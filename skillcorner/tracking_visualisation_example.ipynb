# %%
# %matplotlib widget
from skillcorner.client import SkillcornerClient
skc_client = SkillcornerClient('PUT_YOUR_LOGIN_HERE', 'PUT_YOUR_PASSWORD_HERE')

# %%
skc_client.create_full_visualisation(4320)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
tracking_data = skc_client.get_match_tracking_data(4320)
skc_client.create_full_visualisation(tracking_data)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
skc_client.create_visualisation_per_frame(tracking_data, frame=500)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
